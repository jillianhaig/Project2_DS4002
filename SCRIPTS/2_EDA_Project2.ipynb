# %% [markdown]
# <a href="https://colab.research.google.com/github/jillianhaig/Project2_DS4002/blob/main/SCRIPTS/2_EDA_Project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/jillianhaig/Project2_DS4002 # so we can access data loaded from shared github
# Out:
# Cloning into 'Project2_DS4002'...
# remote: Enumerating objects: 200, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 200 (delta 24), reused 14 (delta 14), pack-reused 166 (from 1)
# Receiving objects: 100% (200/200), 1.89 MiB | 6.21 MiB/s, done.
# Resolving deltas: 100% (75/75), done.

# %%
# import packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# load in final hurricane dataset
hurricane_data = pd.read_csv('/content/Project2_DS4002/DATA/Final Dataset/Hurricane_Dataset.csv')

# %%
# atlantic trend
sns.regplot(data=hurricane_data, x='Year', y='Atlantic_Hurricane_Days',
            scatter_kws={'color': 'blue', 's': 25},
            line_kws={'color': 'black'})
# Out:
# <Axes: xlabel='Year', ylabel='Atlantic_Hurricane_Days'>

# %%
# pacific trend
sns.regplot(data=hurricane_data, x='Year', y='Pacific_Hurricane_Days',
            scatter_kws={'color': 'green', 's': 25},
            line_kws={'color': 'black'})
# Out:
# <Axes: xlabel='Year', ylabel='Pacific_Hurricane_Days'>

# %%
# atlantic + pacific trend
sns.regplot(data=hurricane_data, x='Year', y='Total_Hurricane_Days',
            scatter_kws={'color': 'purple', 's': 25},
            line_kws={'color': 'black'})
# Out:
# <Axes: xlabel='Year', ylabel='Total_Hurricane_Days'>

# %%
# line graph for total hurricane days
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6))
sns.lineplot(data=hurricane_data, x='Year', y='Total_Hurricane_Days', marker='o')

# titles and labels
plt.title('Total Hurricane Days 1971-2021 (Atlantic and Pacific Oceans)', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Total Hurricane Days', fontsize=14)

# show the plot
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# stacked area plot
hurricane_data.set_index('Year', inplace=True)  # set year as the index

plt.figure(figsize=(10, 6))
plt.stackplot(hurricane_data.index, hurricane_data['Pacific_Hurricane_Days'], hurricane_data['Atlantic_Hurricane_Days'], hurricane_data['Total_Hurricane_Days'],
               labels=['Pacific Hurricane Days', 'Atlantic Hurricane Days', 'Total Hurricane Days'])

# titles and labels
plt.title('Stacked Area Plot of Hurricane Days', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Number of Hurricane Days', fontsize=14)
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# plot relationship between CO2 emissions and total hurricane days
sns.regplot(data=hurricane_data, x='Total_Hurricane_Days', y='CO2_emissions',
            scatter_kws={'color': 'black', 's': 25},
            line_kws={'color': 'black'})
# Out:
# <Axes: xlabel='Total_Hurricane_Days', ylabel='CO2_emissions'>

# %%
# find number of rows and columns
hurricane_data.shape
# Out:
# (51, 8)

# %%
# view data
hurricane_data
# Out:
#       Atlantic_Hurricane_Days  Pacific_Hurricane_Days  Total_Hurricane_Days  \
# Year
# 1971                    28.75                   38.50                 67.25
# 1972                     6.25                   33.75                 40.00
# 1973                    10.00                   28.50                 38.50
# 1974                    14.25                   22.75                 37.00
# 1975                    20.50                   26.75                 47.25
# 1976                    25.50                   27.25                 52.75
# 1977                     6.75                    5.25                 12.00
# 1978                    13.50                   51.50                 65.00
# 1979                    21.75                   13.75                 35.50
# 1980                    38.25                   22.75                 61.00
# 1981                    22.50                   18.25                 40.75
# ...

# %%
fig, axes = plt.subplots(3, 3, figsize=(12, 12))

# makes indexing easier
axes = axes.flatten()

# used for for loop below
variables = ['Total_Hurricane_Days', 'Surface_Temperature_Change', 'SurfaceSeaTemp_Annual_Anomaly']

# selects color palette
palette = sns.color_palette("YlGnBu", as_cmap=True)

# loop through each variable and make scatterplot for each one
plot_idx = 0
for var1 in variables:
    for var2 in variables:
        # adds line of best fit and plot
        sns.regplot(x=var1, y=var2, data=hurricane_data, ax=axes[plot_idx], scatter_kws={'s': 80, 'alpha': 0.6}, line_kws={'color':"red",'lw': 2})

        # set titles and labels
        axes[plot_idx].set_xlabel(var1, fontsize=10)
        axes[plot_idx].set_ylabel(var2, fontsize=10)

        # remove ticks for clarity
        axes[plot_idx].tick_params(axis='both', which='major', labelsize=5)

        plot_idx += 1

# prevent overlap
plt.tight_layout()

plt.show()
